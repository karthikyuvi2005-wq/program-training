# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikyuvi2005-wq/program-training/blob/main/pythontraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N=int(input("total number of candies"))
k=int(input("minimum no of candies in the jar"))
T=N
TSOLD=0

c=1
while c==1:
 dem=int(input("enter the customer requirements"))
 if dem>N:
  print("invalid input")
 else:
   N=N-dem
   TSOLD+=dem
   print(dem)
   print("remaining=",N)
   if N<k:
    N=T
    print("remaining=",N)
    C=int(input("do you want to continue(1,0)"))
print("total sold",TSOLD)
# Out:
# total number of candies10
# minimum no of candies in the jar5
# enter the customer requirements3
# 3
# remaining= 7
# enter the customer requirements3
# 3
# remaining= 4
# remaining= 10
# do you want to continue(1,0)1
# enter the customer requirements3
# 3
# remaining= 7

# %%
n=int(input("enter n"))
k=int(input("enter k"))
j=int(input("enter j"))
m=int(input("enter m"))
p=int(input("enter p"))
if k<=0 or j<=0:
      print("invalid input")

noofmonkeys=m//k+p//j


n=n-noofmonkeys
if m%k!=0 or p%j!=0:
      n=n-1
print(n)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2162/2920913755.py in <cell line: 0>()
# ----> 1 n=int(input("enter n"))
#       2 k=int(input("enter k"))
#       3 j=int(input("enter j"))
#       4 m=int(input("enter m"))
#       5 p=int(input("enter p"))
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# Out:
# enter first number1
# enter second number2
# a= 1
# b= 2
# after swapping
# a= 2
# b= 1

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
print("a=",a)
print("b=",b)
a=a^b
b=a^b
a=a^b

print("after swapping")
print(a,b)
a=2
b=5
a,b=b,a
print(a,b)
a,b=2,5
temp=a
a=b
b=temp
print(a,b)
a,b=2,5
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# enter first number2
# enter second number5
# a= 2
# b= 5
# after swapping
# 5 2
# 5 2
# 5 2
# 5 2

# %%
n=int(input("enter no:of candies available in the jar"))
k=int(input("enter number of minimum candies that must be inside JAR ever."))
C=1
R=n
while(C==1):
  M=int(input("Enter amout of candies needed:"))
  if(M>n):
    print("invalid")
  else:
    R=R-M
    if(R<=k):
      R=n
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))

# %% [markdown]
# ## Simple Machine Learning Model Training: Linear Regression

# %% [markdown]
# This example demonstrates the basic steps of a machine learning workflow: data generation, splitting data into training and testing sets, training a linear regression model, making predictions, and evaluating the model's performance. The visualization shows how well the regression line fits the data.

# %% [markdown]
# :
